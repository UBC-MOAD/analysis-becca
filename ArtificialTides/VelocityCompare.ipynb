# %%
import xarray as xr
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %%
file = "/data/rbeutel/analysis/ssc_tidesback/U_new_20190901.nc"
newU = xr.open_dataset(file)
newU
# Out:
# <xarray.Dataset>
# Dimensions:                        (time_counter: 24, y: 898, x: 398, depthu: 40)
# Coordinates:
#   * time_counter                   (time_counter) datetime64[ns] 2019-09-01T0...
#     nav_lat                        (y, x) float32 ...
#     nav_lon                        (y, x) float32 ...
#   * depthu                         (depthu) float32 0.5 1.5 2.5 ... 414.5 441.5
# Dimensions without coordinates: y, x
# Data variables:
#     __xarray_dataarray_variable__  (time_counter, y, x, depthu) float32 ...

# %%
file = "/results2/SalishSea/nowcast-green.201905/01sep19/SalishSea_1h_20190901_20190901_grid_U.nc"
oldU = xr.open_dataset(file)
oldU
# Out:
# <xarray.Dataset>
# Dimensions:               (y: 898, x: 398, nvertex: 4, depthu: 40, axis_nbounds: 2, time_counter: 24)
# Coordinates:
#     nav_lat               (y, x) float32 ...
#     nav_lon               (y, x) float32 ...
#   * depthu                (depthu) float32 0.5 1.5 2.5 3.5 ... 387.6 414.5 441.5
#     time_centered         (time_counter) datetime64[ns] ...
#   * time_counter          (time_counter) datetime64[ns] 2019-09-01T00:30:00 ....
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables:
#     bounds_lon            (y, x, nvertex) float32 ...
#     bounds_lat            (y, x, nvertex) float32 ...
#     area                  (y, x) float32 ...
#     depthu_bounds         (depthu, axis_nbounds) float32 ...
#     vozocrtx              (time_counter, depthu, y, x) float32 ...
#     time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] ...
# Attributes:
# ...

# %%
newU.__xarray_dataarray_variable__.min()
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' ()>
# array(-4.35691547)

# %%
oldU.vozocrtx.min()
# Out:
# <xarray.DataArray 'vozocrtx' ()>
# array(-5.0955224)

# %%
oldU.vozocrtx.max()
# Out:
# <xarray.DataArray 'vozocrtx' ()>
# array(5.50196075)

# %%
newU.__xarray_dataarray_variable__.max()
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' ()>
# array(1.54999995)
