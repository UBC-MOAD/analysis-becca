# %% [markdown]
# # Let's do some learning on the characteristics of the CIOPS West Output!!!

# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
path = "/ocean/mdunphy/NEP36-GPSC4-VAH006/"
filename = "NEP36-GPSC4-VAH006_5d_grid_V_20070406-20070410.nc"

# %%
xr.open_dataset('/ocean/mdunphy/NEP36-GPSC4-VAH006/NEP36-GPSC4-VAH006_5d_grid_T_20070406-20070410.nc')
# Out:
# <xarray.Dataset>
# Dimensions:               (axis_nbounds: 2, deptht: 50, time_counter: 1, x: 715, y: 1021)
# Coordinates:
#     nav_lat               (y, x) float32 ...
#     nav_lon               (y, x) float32 ...
#   * deptht                (deptht) float32 0.494 1.541 ... 5.275e+03 5.728e+03
#     time_centered         (time_counter) datetime64[ns] ...
#   * time_counter          (time_counter) datetime64[ns] 2007-04-08T12:00:00
# Dimensions without coordinates: axis_nbounds, x, y
# Data variables:
#     deptht_bounds         (deptht, axis_nbounds) float32 ...
#     time_centered_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     time_counter_bounds   (time_counter, axis_nbounds) datetime64[ns] ...
#     temp                  (time_counter, deptht, y, x) float32 ...
#     salt                  (time_counter, deptht, y, x) float32 ...
# Attributes:
#     name:         NEP36-GPSC4-VAH006_5d_grid_T
#     description:  Created by xios
#     title:        Created by xios
# ...

# %%
xr.open_dataset('/ocean/mdunphy/mesh_mask.nc')
# Out:
# <xarray.Dataset>
# Dimensions:       (t: 1, x: 715, y: 1021, z: 50)
# Dimensions without coordinates: t, x, y, z
# Data variables:
#     nav_lon       (y, x) float32 ...
#     nav_lat       (y, x) float32 ...
#     nav_lev       (z) float32 ...
#     time_counter  (t) float64 ...
#     tmask         (t, z, y, x) int8 ...
#     umask         (t, z, y, x) int8 ...
#     vmask         (t, z, y, x) int8 ...
#     fmask         (t, z, y, x) int8 ...
#     tmaskutil     (t, y, x) int8 ...
#     umaskutil     (t, y, x) int8 ...
#     vmaskutil     (t, y, x) int8 ...
#     fmaskutil     (t, y, x) int8 ...
#     glamt         (t, y, x) float32 ...
#     glamu         (t, y, x) float32 ...
#     glamv         (t, y, x) float32 ...
#     glamf         (t, y, x) float32 ...
#     gphit         (t, y, x) float32 ...
#     gphiu         (t, y, x) float32 ...
#     gphiv         (t, y, x) float32 ...
#     gphif         (t, y, x) float32 ...
#     e1t           (t, y, x) float64 ...
# ...

# %% [markdown]
# ^ these look like all the same data variables as were in the salishseacast mesh, so dont think i need to chage anything
